# [AIMessage(content="The current weather in San Francisco includes times of sun and clouds with a high of 63°F. Tonight, expect cloudy conditions with periods of rain beginning late, with a low of 54°F. The air quality has reached a high level of pollution, which is unhealthy for sensitive groups, so it's advisable to reduce time spent outside if you're experiencing symptoms like difficulty breathing or throat irritation.", response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 1601, 'total_tokens': 1679, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_64dfa806c7', 'finish_reason': 'stop', 'logprobs': None}, id='run-9267f92b-762e-46f3-82bd-2583e5923335-0')]

# %%
messages = [HumanMessage(content="What about in la?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_kOj27ASewSPVcyzzJeh9tYO8', 'function': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 1691, 'total_tokens': 1713, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_64dfa806c7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-e10ae5af-9390-44c9-b3a7-79caecc37d63-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_kOj27ASewSPVcyzzJeh9tYO8'}])]}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_kOj27ASewSPVcyzzJeh9tYO8'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://world-weather.info/forecast/usa/los_angeles/february-2026/\', \'content\': \'Weather in Los Angeles in February 2026. Los Angeles Weather ... Monday, 23 February. Day. +77°. 3.4. 29.8. 51%. +48°. 06:28 AM. 05:44 PM.\'}, {\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/february-weather/347625\', \'content\': "# Los Angeles, CA\\n\\nLos Angeles\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## February\\n\\n## 2026\\n\\n## Daily\\n\\n## Temperature Graph\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### March 2026\\n\\n### April 2026\\n\\n### May 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nWinter Weather\\n\\nDangerous nor\'easter, blizzard to rage from Delaware, NYC to Boston\\n\\n47 minutes ago [...] 47 minutes ago\\n\\nUpdates: Blockbuster blizzard conditions begin in I-95 corridor\\n\\nLATEST ENTRY\\n\\nNew Jersey power outages surge as statewide travel ban takes effect\\n\\n9 hours ago\\n\\nWinter Weather\\n\\nMore winter weather on the way behind blockbuster blizzard\\n\\n1 hour ago\\n\\nWinter Weather\\n\\nAtmospheric river to blast West Coast with more flooding, heavy snow\\n\\n46 minutes ago\\n\\nWeather Forecasts\\n\\nFrom 80s F to freezing: Florida faces cold blast, growing fire danger\\n\\n59 minutes ago\\n\\nFeatured Stories\\n\\nWinter Weather\\n\\nSearch teams working to recover bodies of skiers killed in avalanche\\n\\n3 days ago\\n\\nWeather Forecasts\\n\\nWildfire season to ramp up early as drought covers over 40% of the US\\n\\n4 days ago\\n\\nWeather News\\n\\nBald eagle rescued from floating ice on New York\'s Hudson River\\n\\n3 days ago\\n\\nClimate [...] 3 days ago\\n\\nClimate\\n\\n75% of global coffee supply faces rising extreme heat, analysis says\\n\\n3 days ago\\n\\nTravel\\n\\nThe island with an air-conditioned ‘forest’ to cope with summers\\n\\n3 days ago\\n\\n## Weather Near Los Angeles:\\n\\n...\\n\\n...\\n\\n..."}]', name='tavily_search_results_json', tool_call_id='call_kOj27ASewSPVcyzzJeh9tYO8')]}
# {'messages': [AIMessage(content='The current weather in Los Angeles is warm with a temperature around 77°F. The day is expected to be mostly sunny.', response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 2339, 'total_tokens': 2365, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_64dfa806c7', 'finish_reason': 'stop', 'logprobs': None}, id='run-88d92170-a8ef-4329-8f6a-6784378d56d4-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content="Currently, Los Angeles is warmer than San Francisco, with a temperature of about 77°F compared to San Francisco's 63°F.", response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 2377, 'total_tokens': 2405, 'prompt_tokens_details': {'cached_tokens': 1664, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_64dfa806c7', 'finish_reason': 'stop', 'logprobs': None}, id='run-88b859d7-f822-448d-87ee-cdbfd3cb36ea-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content="Could you please clarify what you're comparing to determine which is warmer? Are you comparing two specific locations, types of clothing, materials, or something else? Let me know so I can provide the appropriate information.", response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 149, 'total_tokens': 192, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_f9f4fb6dbf', 'finish_reason': 'stop', 'logprobs': None}, id='run-c8194a58-cf2e-4ee8-87ed-186ae62fb9ea-0')]}

# %% [markdown]
# ## Streaming tokens

# %%
from langgraph.checkpoint.aiosqlite import AsyncSqliteSaver

memory = AsyncSqliteSaver.from_conn_string(":memory:")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the weather in SF?")]
thread = {"configurable": {"thread_id": "4"}}
async for event in abot.graph.astream_events({"messages": messages}, thread, version="v1"):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        content = event["data"]["chunk"].content
        if content:
            # Empty content in the context of OpenAI means
            # that the model is asking for a tool to be invoked.
            # So we only print non-empty content
            print(content, end="|")
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_GiHnpbt7P6kuX4g2n6imqDXI'}
# /usr/local/lib/python3.11/site-packages/langchain_core/_api/beta_decorator.py:87: LangChainBetaWarning: This API is in beta and may change in the future.
#   warn_beta(
# Back to the model!
# The| current| weather| in| San| Francisco| is| characterized| by| times| of| sun| and| clouds|,| with| a| high| of| |63|°F|.| Tonight|,| it| will| be| cloudy| with| periods| of| rain| expected| late|,| and| a| low| of| |54|°F|.| Expect| rainy| weather| to| continue| from| late| tonight| through| late| tomorrow| night|.|
